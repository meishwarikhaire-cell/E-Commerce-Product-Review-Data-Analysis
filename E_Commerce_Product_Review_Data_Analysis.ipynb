# %%
import pandas as pd
import random

random.seed(42)

# Generate 100 product reviews
categories = ['Electronics', 'Clothing', 'Books', 'Sports']
cities = ['Mumbai', 'Delhi', 'Bangalore', 'Chennai']

data = []
for i in range(100):
    data.append({
        'product': random.choice(['Laptop', 'T-Shirt', 'Novel', 'Shoes', 'Phone']),
        'category': random.choice(categories),
        'rating': random.randint(1, 5),
        'price': random.randint(500, 20000),
        'city': random.choice(cities)
    })

df = pd.DataFrame(data)

# %%
#Task 1: Preview and Explore
# Preview and Explore the Dataset
# Display First 10 Rows
# Use head(10) to see the first 10 records.
df.head(10)
# Out:
#    product     category  rating  price       city
# 0   Laptop  Electronics       3   8524      Delhi
# 1  T-Shirt  Electronics       5   3348    Chennai
# 2   Laptop  Electronics       1   7664      Delhi
# 3    Phone  Electronics       5   7015    Chennai
# 4  T-Shirt       Sports       5   9615     Mumbai
# 5  T-Shirt       Sports       3   9605      Delhi
# 6  T-Shirt        Books       1   3539    Chennai
# 7   Laptop        Books       3   9167     Mumbai
# 8    Shoes  Electronics       4   3082  Bangalore
# 9    Phone        Books       5   6800     Mumbai

# %%
# Display Last 5 Rows
# Use tail(5) to see the last records.
df.tail(5)
# Out:
#     product  category  rating  price     city
# 95  T-Shirt  Clothing       1   3992  Chennai
# 96  T-Shirt  Clothing       5  15722   Mumbai
# 97    Phone  Clothing       1  15457    Delhi
# 98    Shoes     Books       4  17040  Chennai
# 99    Phone    Sports       2  16054  Chennai

# %%
#Find Dataset Dimensions
# Use shape to check the number of rows and columns.

df.shape
# Out:
# (100, 5)

# %%
# Get Dataset Information
# Use info() to see column details.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   product   100 non-null    object
#  1   category  100 non-null    object
#  2   rating    100 non-null    int64
#  3   price     100 non-null    int64
#  4   city      100 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 4.0+ KB

# %%
# Generate Summary Statistics
# Use describe() to analyze numerical columns.

df.describe()
# Out:
#            rating         price
# count  100.000000    100.000000
# mean     2.990000   9679.400000
# std      1.452932   5731.646043
# min      1.000000    606.000000
# 25%      2.000000   4129.250000
# 50%      3.000000   9190.000000
# 75%      4.000000  14976.500000
# max      5.000000  19777.000000

# %% [markdown]
# Explanation:
#
# mean → average value
#
# std → standard deviation
#
# min / max → smallest & largest values
#
# This helps understand customer ratings and price distribution.

# %%
# Access Columns
# Access Single Column

df['rating']
# Out:
# 0     3
# 1     5
# 2     1
# 3     5
# 4     5
#      ..
# 95    1
# 96    5
# 97    1
# 98    4
# 99    2
# Name: rating, Length: 100, dtype: int64

# %%
# Access Multiple Columns
df[['rating', 'price']]
# Out:
#     rating  price
# 0        3   8524
# 1        5   3348
# 2        1   7664
# 3        5   7015
# 4        5   9615
# ..     ...    ...
# 95       1   3992
# 96       5  15722
# 97       1  15457
# 98       4  17040
# 99       2  16054
#
# [100 rows x 2 columns]

# %%
#Task 2: Filter with Conditions
#Filter All Reviews from Bangalore

mask = df['city'] == 'Bangalore'
bangalore_df = df[mask]

# %%
#Products with 5-star rating AND price > 10000

df[(df['rating'] == 5) & (df['price'] > 10000)]
# Out:
#     product     category  rating  price       city
# 19    Phone       Sports       5  13587  Bangalore
# 20  T-Shirt     Clothing       5  16671     Mumbai
# 28    Phone  Electronics       5  11121    Chennai
# 39    Phone     Clothing       5  19381    Chennai
# 50    Novel       Sports       5  16447      Delhi
# 62  T-Shirt       Sports       5  10412     Mumbai
# 96  T-Shirt     Clothing       5  15722     Mumbai

# %%
#Electronics OR Books with rating < 3

df[((df['category'] == 'Electronics') | (df['category'] == 'Books')) & (df['rating'] < 3)]
# Out:
#     product     category  rating  price       city
# 2    Laptop  Electronics       1   7664      Delhi
# 6   T-Shirt        Books       1   3539    Chennai
# 15    Novel  Electronics       2   1551  Bangalore
# 16    Shoes        Books       1   7413  Bangalore
# 21   Laptop  Electronics       2   5742    Chennai
# 35   Laptop        Books       1  19777      Delhi
# 37  T-Shirt  Electronics       1  11327     Mumbai
# 42    Shoes  Electronics       1   2486    Chennai
# 43    Novel  Electronics       2   6778      Delhi
# 46    Phone  Electronics       1  18213     Mumbai
# 51  T-Shirt        Books       2   2416     Mumbai
# 52    Novel  Electronics       1  19642    Chennai
# 61    Novel  Electronics       2  12608  Bangalore
# 63    Phone        Books       1   4900  Bangalore
# 67    Shoes        Books       1    616  Bangalore
# 68  T-Shirt        Books       2  14978    Chennai
# 69    Phone  Electronics       1   2965      Delhi
# ...

# %% [markdown]
# Why We Use & Instead of and
#
# In Pandas, we must use & and | for element-wise logical operations.
#
# Operator	Used For
# and	Normal Python boolean logic
# &	Pandas / NumPy element-wise comparison

# %%
df[(df['rating'] == 5) & (df['price'] > 10000)]
# Out:
#     product     category  rating  price       city
# 19    Phone       Sports       5  13587  Bangalore
# 20  T-Shirt     Clothing       5  16671     Mumbai
# 28    Phone  Electronics       5  11121    Chennai
# 39    Phone     Clothing       5  19381    Chennai
# 50    Novel       Sports       5  16447      Delhi
# 62  T-Shirt       Sports       5  10412     Mumbai
# 96  T-Shirt     Clothing       5  15722     Mumbai

# %%
#Task 3: Value Counts and Visualization
#Count Reviews per Category
df['category'].value_counts()
# Out:
# category
# Clothing       29
# Electronics    28
# Sports         22
# Books          21
# Name: count, dtype: int64

# %%
#Find Which City Has the Most Reviews

df['city'].value_counts()
# Out:
# city
# Delhi        29
# Bangalore    26
# Chennai      24
# Mumbai       21
# Name: count, dtype: int64

# %%
#Create a Bar Chart for Category Reviews

df['category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %%
#Create a Histogram of Ratings

df['rating'].plot(kind='hist', bins=5)
# Out:
# <Axes: ylabel='Frequency'>
